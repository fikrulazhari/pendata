# %% [markdown]
# #Decison Tree

# %% [markdown]
# ##Data hewan dengan genus sama
#
# Berikut adalah contoh 15 data hewan dari 3 kelas (spesies berbeda) dengan 2 fitur, semua masih dalam genus yang sama (Equus), Equs Caballus (kuda), Equs Zebra (zebra), Equs asinus (keledai)
#
# | No | Panjang (m) | Berat (kg) | Spesies          |
# | -- | ----------- | ---------- | ---------------- |
# | 1  | 2.4         | 500        | *Equus caballus* |
# | 2  | 2.5         | 520        | *Equus caballus* |
# | 3  | 2.6         | 540        | *Equus caballus* |
# | 4  | 2.3         | 490        | *Equus caballus* |
# | 5  | 2.2         | 480        | *Equus caballus* |
# | 6  | 2.1         | 320        | *Equus zebra*    |
# | 7  | 2.2         | 330        | *Equus zebra*    |
# | 8  | 2.3         | 340        | *Equus zebra*    |
# | 9  | 2.1         | 310        | *Equus zebra*    |
# | 10 | 2.0         | 300        | *Equus zebra*    |
# | 11 | 1.9         | 250        | *Equus asinus*   |
# | 12 | 1.8         | 240        | *Equus asinus*   |
# | 13 | 2.0         | 260        | *Equus asinus*   |
# | 14 | 1.9         | 255        | *Equus asinus*   |
# | 15 | 2.1         | 270        | *Equus asinus*   |

# %% [markdown]
# ##perhitungan Manual
#
# ---
#
# ## 📏 Fitur 1: **Panjang Tubuh (cm)**
#
# ### ✅ Threshold = **225 cm**
#
# **Split Data:**
#
# * **Group Left (≤ 225):** No 6, 7, 9, 10, 11, 12, 13, 14, 15 → 9 data
#
#   * zebra: 4 (No 6, 7, 9, 10)
#   * asinus: 5 (No 11–15)
#
# * **Group Right (> 225):** No 1, 2, 3, 4, 5, 8 → 6 data
#
#   * caballus: 5 (No 1–5)
#   * zebra: 1 (No 8)
#
# ---
#
# ### 🔸 Entropy(D) Awal
#
# Kelas seimbang: 5 caballus, 5 zebra, 5 asinus
#
# $$
# Entropy(D) = -3 \cdot \left( \frac{1}{3} \cdot \log_2 \frac{1}{3} \right) ≈ 1.585
# $$
#
# ---
#
# ### 🔸 Entropy(Left)
#
# * zebra = 4/9
# * asinus = 5/9
#
# $$
# Entropy(Left) = -\frac{4}{9} \log_2 \frac{4}{9} - \frac{5}{9} \log_2 \frac{5}{9} ≈ 0.991
# $$
#
# ---
#
# ### 🔸 Entropy(Right)
#
# * caballus = 5/6
# * zebra = 1/6
#
# $$
# Entropy(Right) = -\frac{5}{6} \log_2 \frac{5}{6} - \frac{1}{6} \log_2 \frac{1}{6} ≈ 0.650
# $$
#
# ---
#
# ### 🔹 Information Gain:
#
# $$
# IG = 1.585 - \left( \frac{9}{15} \cdot 0.991 + \frac{6}{15} \cdot 0.650 \right) \\
# IG = 1.585 - (0.5946 + 0.26) = \boxed{0.730}
# $$
#
# ---
#
# ### 🔸 Gini(D):
#
# $$
# Gini(D) = 1 - 3 \cdot \left( \frac{1}{3} \right)^2 = 1 - \frac{1}{3} = 0.667
# $$
#
# ---
#
# ### 🔸 Gini(Left)
#
# * zebra = 4/9
# * asinus = 5/9
#
# $$
# Gini(Left) = 1 - \left( \frac{4}{9} \right)^2 - \left( \frac{5}{9} \right)^2 = 1 - 0.1975 - 0.3086 = \boxed{0.494}
# $$
#
# ---
#
# ### 🔸 Gini(Right)
#
# * caballus = 5/6
# * zebra = 1/6
#
# $$
# Gini(Right) = 1 - \left( \frac{5}{6} \right)^2 - \left( \frac{1}{6} \right)^2 = 1 - 0.694 - 0.028 = \boxed{0.278}
# $$
#
# ---
#
# ### 🔹 Gini Split:
#
# $$
# Gini_{split} = \frac{9}{15} \cdot 0.494 + \frac{6}{15} \cdot 0.278 = 0.2964 + 0.1112 = \boxed{0.408}
# $$
#
# ---
#
# ## ⚖️ Fitur 2: **Berat Tubuh (kg)**
#
# ### ✅ Threshold = **310 kg**
#
# **Split Data:**
#
# * **Group Left (≤ 310):** No 6–10 (zebra), No 11–15 (asinus), No 8 (caballus) → 10 data
#
#   * zebra: 4
#   * asinus: 5
#   * caballus: 1
#
# * **Group Right (> 310):** No 1–5 → 5 data
#
#   * caballus: 4
#   * zebra: 1
#
# ---
#
# ### 🔸 Entropy(Left)
#
# $$
# p_z = 4/10,\quad p_a = 5/10,\quad p_c = 1/10
# $$
#
# $$
# Entropy(Left) = -\left( \frac{4}{10} \log_2 \frac{4}{10} + \frac{5}{10} \log_2 \frac{5}{10} + \frac{1}{10} \log_2 \frac{1}{10} \right) ≈ 1.361
# $$
#
# ---
#
# ### 🔸 Entropy(Right)
#
# * caballus = 0.8
# * zebra = 0.2
#
# $$
# Entropy(Right) = -0.8 \log_2 0.8 - 0.2 \log_2 0.2 ≈ 0.721
# $$
#
# ---
#
# ### 🔹 Information Gain:
#
# $$
# IG = 1.585 - \left( \frac{10}{15} \cdot 1.361 + \frac{5}{15} \cdot 0.721 \right) \\
# IG = 1.585 - (0.907 + 0.240) = \boxed{0.438}
# $$
#
# ---
#
# ### 🔸 Gini(Left)
#
# $$
# Gini = 1 - (0.4)^2 - (0.5)^2 - (0.1)^2 = 1 - 0.16 - 0.25 - 0.01 = \boxed{0.580}
# $$
#
# ---
#
# ### 🔸 Gini(Right)
#
# $$
# Gini = 1 - (0.8)^2 - (0.2)^2 = 1 - 0.64 - 0.04 = \boxed{0.320}
# $$
#
# ---
#
# ### 🔹 Gini Split:
#
# $$
# Gini_{split} = \frac{10}{15} \cdot 0.580 + \frac{5}{15} \cdot 0.320 = 0.387 + 0.106 = \boxed{0.493}
# $$
#
# ---
#
# ## ✅ RINGKASAN AKHIR:
#
# | Fitur         | Threshold | IG    | Gini Split |
# | ------------- | --------- | ----- | ---------- |
# | Panjang Tubuh | 225 cm    | 0.730 | 0.408      |
# | Berat Tubuh   | 310 kg    | 0.438 | 0.493      |
#
# ➡️ **Kesimpulan:** Threshold terbaik berdasarkan **IG** dan **Gini terendah** adalah pada **Fitur Panjang Tubuh dengan threshold 225 cm**.

# %% [markdown]
# ##Visualisai Decision Tree

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.preprocessing import LabelEncoder

# === Data kuda ===
data = {
    "Panjang Tubuh (cm)": [280, 290, 275, 265, 285, 210, 215, 220, 230, 225, 190, 200, 195, 185, 180],
    "Berat Tubuh (kg)": [400, 410, 405, 390, 415, 320, 315, 310, 305, 300, 200, 205, 195, 190, 185],
    "Kelas": [
        "caballus", "caballus", "caballus", "caballus", "caballus",
        "zebra", "zebra", "zebra", "zebra", "zebra",
        "asinus", "asinus", "asinus", "asinus", "asinus"
    ]
}

df = pd.DataFrame(data)

# === Label Encoding ===
le = LabelEncoder()
df['Label'] = le.fit_transform(df['Kelas'])  # misal: asinus=0, caballus=1, zebra=2

# === Fitur dan Target ===
X = df[["Panjang Tubuh (cm)", "Berat Tubuh (kg)"]]
y = df["Label"]

# === Train Decision Tree ===
clf = DecisionTreeClassifier(criterion="gini", max_depth=3, random_state=42)
clf.fit(X, y)

# === Tampilkan aturan pohon keputusan ===
print("\n=== Pohon Keputusan (Decision Tree) ===")
tree_rules = export_text(clf, feature_names=list(X.columns))
print(tree_rules)
# Out:
# === Pohon Keputusan (Decision Tree) ===
# |--- Panjang Tubuh (cm) <= 205.00
# |   |--- class: 0
# |--- Panjang Tubuh (cm) >  205.00
# |   |--- Berat Tubuh (kg) <= 355.00
# |   |   |--- class: 2
# |   |--- Berat Tubuh (kg) >  355.00
# |   |   |--- class: 1

# %% [markdown]
# ##Visualisasi Splitting

# %%
# Uji 2 Data Baru
uji_baru = pd.DataFrame({
    'Panjang Tubuh (cm)': [235, 248],
    'Berat Tubuh (kg)': [225, 215]
})

prediksi = clf.predict(uji_baru)
hasil = le.inverse_transform(prediksi)

print("\n=== Prediksi 2 Data Baru ===")
for i, (p, b) in enumerate(zip(uji_baru['Panjang Tubuh (cm)'], uji_baru['Berat Tubuh (kg)'])):
    print(f"Data {i+1}: Panjang={p}, Berat={b} → Prediksi: {hasil[i]}")

# Visualisasi Decision Boundary dengan data uji dan garis split
print("\n=== Visualisasi Decision Boundary ===")
plot_colors = "ry"  # 2 kelas
plot_step = 1.0

x_min, x_max = X['Panjang Tubuh (cm)'].min() - 10, X['Panjang Tubuh (cm)'].max() + 10
y_min, y_max = X['Berat Tubuh (kg)'].min() - 10, X['Berat Tubuh (kg)'].max() + 10

xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                     np.arange(y_min, y_max, plot_step))

grid = np.c_[xx.ravel(), yy.ravel()]
grid_df = pd.DataFrame(grid, columns=['Panjang Tubuh (cm)', 'Berat Tubuh (kg)'])
Z = clf.predict(grid_df)
Z = Z.reshape(xx.shape)

plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu, alpha=0.6)

# Plot titik data training
for label, color in zip([0, 1], plot_colors):
    idx = np.where(y == label)
    plt.scatter(X.iloc[idx]['Panjang Tubuh (cm)'], X.iloc[idx]['Berat Tubuh (kg)'],
                c=color, edgecolor='k', label=le.inverse_transform([label])[0])

# Plot data uji
plt.scatter(uji_baru['Panjang Tubuh (cm)'], uji_baru['Berat Tubuh (kg)'],
            c='black', marker='X', s=100, label='Data Uji')

# Tambahkan garis splitting dari decision tree
def plot_splits(tree, feature_names):
    drawn_lines = set()
    for node in range(tree.node_count):
        feature = tree.feature[node]
        threshold = tree.threshold[node]
        if feature != -2:  # bukan leaf node
            feat_name = feature_names[feature]
            if (feat_name, threshold) not in drawn_lines:
                if feat_name == 'Panjang Tubuh (cm)':
                    plt.axvline(x=threshold, color='k', linestyle='--', alpha=0.7, label=f"Split {feat_name}={threshold:.1f}")
                elif feat_name == 'Berat Tubuh (kg)':
                    plt.axhline(y=threshold, color='k', linestyle='--', alpha=0.7, label=f"Split {feat_name}={threshold:.1f}")
                drawn_lines.add((feat_name, threshold))
            else:
                # tanpa label supaya legend tidak duplikat
                if feat_name == 'Panjang Tubuh (cm)':
                    plt.axvline(x=threshold, color='k', linestyle='--', alpha=0.7)
                elif feat_name == 'Berat Tubuh (kg)':
                    plt.axhline(y=threshold, color='k', linestyle='--', alpha=0.7)

plot_splits(clf.tree_, list(X.columns))

plt.xlabel("Panjang Tubuh (cm)")
plt.ylabel("Berat Tubuh (kg)")
plt.title("Decision Boundary dengan Data Uji dan Garis Split (Data Kuda)")
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Prediksi 2 Data Baru ===
# Data 1: Panjang=235, Berat=225 → Prediksi: zebra
# Data 2: Panjang=248, Berat=215 → Prediksi: zebra
#
# === Visualisasi Decision Boundary ===

# %% [markdown]
# ##Visualisasi Splitting Setelah ada 2 Data Baru

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Asumsi data kuda dan model sudah siap:
# X = fitur dataframe (Panjang Tubuh dan Berat Tubuh)
# y = label encoded kelas (0 dan 1)
# clf = decision tree classifier yang sudah fit
# le = label encoder dengan kelas asli
# uji_baru = data uji dataframe

print("\n=== Visualisasi Decision Boundary ===")
plot_colors = "ry"  # r = kelas 0, y = kelas 1
plot_step = 1.0

x_min, x_max = X['Panjang Tubuh (cm)'].min() - 10, X['Panjang Tubuh (cm)'].max() + 10
y_min, y_max = X['Berat Tubuh (kg)'].min() - 10, X['Berat Tubuh (kg)'].max() + 10

xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                     np.arange(y_min, y_max, plot_step))

grid = np.c_[xx.ravel(), yy.ravel()]
grid_df = pd.DataFrame(grid, columns=['Panjang Tubuh (cm)', 'Berat Tubuh (kg)'])
Z = clf.predict(grid_df)
Z = Z.reshape(xx.shape)

plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, cmap=plt.cm.RdYlBu, alpha=0.6)

# Plot titik data training
for label, color in zip([0, 1], plot_colors):
    idx = np.where(y == label)
    plt.scatter(X.iloc[idx]['Panjang Tubuh (cm)'], X.iloc[idx]['Berat Tubuh (kg)'],
                c=color, edgecolor='k', label=le.inverse_transform([label])[0])

# Plot data uji
plt.scatter(uji_baru['Panjang Tubuh (cm)'], uji_baru['Berat Tubuh (kg)'],
            c='black', marker='X', s=100, label='Data Uji')

plt.xlabel("Panjang Tubuh (cm)")
plt.ylabel("Berat Tubuh (kg)")
plt.title("Decision Boundary (Panjang vs Berat) - Data Kuda")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# === Visualisasi Decision Boundary ===

# %% [markdown]
# ##Visualisasi Decision Tree dalam bentuk gambar

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Asumsikan clf, le, dan data sudah siap (seperti contoh sebelumnya)

plt.figure(figsize=(12, 3))
plot_tree(
    clf,
    feature_names=["Panjang Tubuh (cm)", "Berat Tubuh (kg)"],
    class_names=le.classes_,  # nama kelas asli dari LabelEncoder
    filled=True,
    rounded=True,
    impurity=True  # tampilkan nilai Gini di node
)
plt.title("Decision Tree untuk Equs Caballus (kuda), Equs Zebra (zebra), Equs asinus (keledai)")
plt.tight_layout()
plt.show()

# %%
print("=== Rules ===")
print("RULE 1: Jika Panjang Tubuh (cm) <= 252.5 Maka Kelas = Keledai")
print("RULE 2: Jika Panjang Tubuh (cm) > 252.5 dan Berat Tubuh (kg) <= 205 Maka Kelas = Zebra")
print("RULE 3: Jika Panjang Tubuh (cm) > 252.5 dan Berat Tubuh (kg) > 205 Maka Kelas = Kuda")
# Out:
# === Rules ===
# RULE 1: Jika Panjang Tubuh (cm) <= 252.5 Maka Kelas = Keledai
# RULE 2: Jika Panjang Tubuh (cm) > 252.5 dan Berat Tubuh (kg) <= 205 Maka Kelas = Zebra
# RULE 3: Jika Panjang Tubuh (cm) > 252.5 dan Berat Tubuh (kg) > 205 Maka Kelas = Kuda
