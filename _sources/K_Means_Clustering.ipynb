# %% [markdown]
# # **Algoritma *K-Means***

# %% [markdown]
# ## **Pengertian *K-Means Clustering***
#
# *K-Means Clustering*  adalah teknik pengelompokan data yang memisahkan data ke dalam cluster, mengelompokkan data dengan fitur yang sama bersama-sama dan mengelompokkan data dengan karakteristik yang berbeda ke dalam kelompok yang berbeda dengan centroid sebagai acuannya. Metode k-means membagi data menjadi beberapa kelompok sehingga data dengan karakteristik yang sama berada pada cluster yang sama dan data dengan karakteristik yang berbeda berada pada cluster yang berbeda
#
#
# ## **Manfaat *Clustering***
#
#
# - Clustering merupakan metode segmentasi data yang sangat berguna dalam prediksi dan analisa masalah bisnis tertentu. Misalnya Segmentasi pasar, marketing dan pemetaan zonasi wilayah.
# - Identifikasi obyek dalam bidang berbagai bidang seperti computer vision dan image processing.
#
# Hasil clustering yang baik akan menghasilkan tingkat kesamaan yang tinggi dalam satu kelas dan tingkat kesamaan yang rendah antar kelas. Kesamaan yang dimaksud merupakan pengukuran secaranumeric terhadap dua buah objek. Nilai kesamaan antar kedua objek akan semakin tinggi jika kedua objek yang dibandingkan memiliki kemiripan yang tinggi. Begitu juga dengan sebaliknya. Kualitas hasil clustering sangat bergantung pada metode yang dipakai

# %% [markdown]
# ## **Inertia (Sum Square error/SSE)**
#
#
# Dalam konteks algoritma *K-Means Clustering*, *inertia* (Sum Square error/SSE) adalah salah satu metrik evaluasi untuk menilai seberapa baik data dikelompokkan ke dalam klaster serta mengukur jumlah total jarak kuadrat antara setiap titik data dan pusat klaster (centroid) tempat titik tersebut.
#
# Inertia didefinisikan sebagai:
#
# $$
# \text{Inertia} = \sum_{i=1}^{n} \left\| x_i - \mu_{c_i} \right\|^2
# $$
#
# **Penjelasan Notasi**
# - $x_i$: Titik data ke-$i$
# - $\mu_{c_i}$: Centroid dari klaster tempat $x_i$ berada
# - $\left\| x_i - \mu_{c_i} \right\|^2$: Jarak Euclidean kuadrat antara $x_i$ dan centroid-nya
# - $n$: Jumlah total data

# %% [markdown]
# ## **Silhouette Analysis**
#
#
# Silhouette Analysis adalah metrik evaluasi lain yang lebih baik dari inertia dalam banyak kasus untuk mengevaluasi hasil clustering, seperti pada K-Means, karena mempertimbangkan dua hal sekaligus yaitu:
#
# - Kepadatan dalam klaster
#
# - Jarak antar klaster
#
# Silhouette Analysis mengukur seberapa mirip suatu titik data dengan klasternya sendiri dibandingkan dengan klaster terdekat lainnya. Rumusnya adalah:
#
# $$
# s(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}
# $$
#
# **Penjelasan Notasi**:
# - $a(i)$: Rata-rata jarak dari titik $i$ ke semua titik lain dalam klaster yang sama (cohesion)
# - $b(i)$: Rata-rata jarak dari titik $i$ ke semua titik dalam klaster terdekat yang bukan miliknya (separation)
# - $s(i)$: Skor silhouette untuk titik $i$, dengan nilai antara -1 dan 1
#
# Nilai skor $s(i)$ ditafsirkan sebagai berikut:
# - Jika $s(i) \approx 1$, maka titik berada jauh dari klaster lain dan cocok dengan klasternya
# - Jika $s(i) \approx 0$, maka titik berada di antara dua klaster
# - Jika $s(i) \approx -1$, maka titik bisa jadi salah masuk klaster
#
# Untuk mengevaluasi seluruh hasil clustering, digunakan rata-rata dari semua $s(i)$:
#
# $$
# S = \frac{1}{n} \sum_{i=1}^{n} s(i)
# $$
#
# - $n$: Jumlah total data
# - $S$: Silhouette score rata-rata seluruh data

# %% [markdown]
# ## **Implementasi dengan menggunakan data Iris**

# %%
# %pip install pymysql
# %pip install psycopg2
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.11/dist-packages (2.9.10)

# %% [markdown]
# ## **Library yang digunakan**

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics import silhouette_score
import psycopg2
import pymysql
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## **Pengumpulan Data**

# %%
def get_pg_data():
    conn = psycopg2.connect(
        host="pg-3d9a1619-abdillahfikrulazhari-be31.g.aivencloud.com",
        user="avnadmin",
        password="AVNS_mSKvdrH9xCsL8Cs8TAP",
        database="defaultdb",
        port=10201
    )
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM iris_postgresql")
    data = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]  # Ambil nama kolom
    cursor.close()
    conn.close()

    return pd.DataFrame(data, columns=columns)

def get_mysql_data():
    conn = pymysql.connect(
        host="mysql-1790848a-abdillahfikrulazhari-be31.g.aivencloud.com",
        user="avnadmin",
        password="AVNS_yeZaBHu3-BtJnqexe9A",
        database="iris_mysql",
        port=10201
    )
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM irismysql")
    data = cursor.fetchall()
    columns = [desc[0] for desc in cursor.description]  # Ambil nama kolom
    cursor.close()
    conn.close()

    return pd.DataFrame(data, columns=columns)

# Ambil data dari kedua database
df_postgresql = get_pg_data()
df_mysql = get_mysql_data()

# Gabungkan berdasarkan kolom 'id' dan 'Class'
df_merged = pd.merge(df_mysql, df_postgresql, on=["id", "class"], how="inner")

# Cetak semua data hasil gabungan tanpa indeks
print(df_merged.to_string(index=False))
# Out:
#  id           class  petal_length  petal_width  sepal_length  sepal_width
#   1     Iris-setosa          14.0          2.0          20.0         15.0
#   2     Iris-setosa          14.0          2.0          40.9         30.0
#   3     Iris-setosa          13.0          2.0          19.0         22.0
#   4     Iris-setosa          15.0          2.0          23.0         24.0
#   5     Iris-setosa          14.0          2.0          17.0         25.0
#   6     Iris-setosa           1.7          0.4           5.4          3.9
#   7     Iris-setosa           1.4          0.3           4.6          3.4
#   8     Iris-setosa           1.5          0.2           5.0          3.4
#   9     Iris-setosa           1.4          0.2           4.4          2.9
#  10     Iris-setosa           1.5          0.1           4.9          3.1
#  11     Iris-setosa           1.5          0.2           5.4          3.7
#  12     Iris-setosa           1.6          0.2           4.8          3.4
#  13     Iris-setosa           1.4          0.1           4.8          3.0
#  14     Iris-setosa           1.1          0.1           4.3          3.0
#  15     Iris-setosa           1.2          0.2           5.8          4.0
#  16     Iris-setosa           1.5          0.4           5.7          4.4
#  17     Iris-setosa           1.3          0.4           5.4          3.9
#  18     Iris-setosa           1.4          0.3           5.1          3.5
#  19     Iris-setosa           1.7          0.3           5.7          3.8
#  20     Iris-setosa           1.5          0.3           5.1          3.8
#  21     Iris-setosa           1.7          0.2           5.4          3.4
#  22     Iris-setosa           1.5          0.4           5.1          3.7
#  23     Iris-setosa           1.0          0.2           4.6          3.6
#  24     Iris-setosa           1.7          0.5           5.1          3.3
#  25     Iris-setosa           1.9          0.2           4.8          3.4
#  26     Iris-setosa           1.6          0.2           5.0          3.0
#  27     Iris-setosa           1.6          0.4           5.0          3.4
#  28     Iris-setosa           1.5          0.2           5.2          3.5
#  29     Iris-setosa           1.4          0.2           5.2          3.4
#  30     Iris-setosa           1.6          0.2           4.7          3.2
#  31     Iris-setosa           1.6          0.2           4.8          3.1
#  32     Iris-setosa           1.5          0.4           5.4          3.4
#  33     Iris-setosa           1.5          0.1           5.2          4.1
#  34     Iris-setosa           1.4          0.2           5.5          4.2
#  35     Iris-setosa           1.5          0.1           4.9          3.1
#  36     Iris-setosa           1.2          0.2           5.0          3.2
#  37     Iris-setosa           1.3          0.2           5.5          3.5
#  38     Iris-setosa           1.5          0.1           4.9          3.1
#  39     Iris-setosa           1.3          0.2           4.4          3.0
#  40     Iris-setosa           1.5          0.2           5.1          3.4
#  41     Iris-setosa           1.3          0.3           5.0          3.5
#  42     Iris-setosa           1.3          0.3           4.5          2.3
#  43     Iris-setosa           1.3          0.2           4.4          3.2
#  44     Iris-setosa           1.6          0.6           5.0          3.5
#  45     Iris-setosa           1.9          0.4           5.1          3.8
#  46     Iris-setosa           1.4          0.3           4.8          3.0
#  47     Iris-setosa           1.6          0.2           5.1          3.8
#  48     Iris-setosa           1.4          0.2           4.6          3.2
#  49     Iris-setosa           1.5          0.2           5.3          3.7
#  50     Iris-setosa           1.4          0.2           5.0          3.3
#  51 Iris-versicolor          47.0         14.0          17.0         20.0
#  52 Iris-versicolor          45.0         15.0          19.0         21.0
#  53 Iris-versicolor          49.0         15.0          18.0         22.0
#  54 Iris-versicolor          40.0         13.0          20.0         23.0
#  55 Iris-versicolor          46.0         15.0          15.0         24.0
#  56 Iris-versicolor           4.5          1.3           5.7          2.8
#  57 Iris-versicolor           4.7          1.6           6.3          3.3
#  58 Iris-versicolor           3.3          1.0           4.9          2.4
#  59 Iris-versicolor           4.6          1.3           6.6          2.9
#  60 Iris-versicolor           3.9          1.4           5.2          2.7
#  61 Iris-versicolor           3.5          1.0           5.0          2.0
#  62 Iris-versicolor           4.2          1.5           5.9          3.0
#  63 Iris-versicolor           4.0          1.0           6.0          2.2
#  64 Iris-versicolor           4.7          1.4           6.1          2.9
#  65 Iris-versicolor           3.6          1.3           5.6          2.9
#  66 Iris-versicolor           4.4          1.4           6.7          3.1
#  67 Iris-versicolor           4.5          1.5           5.6          3.0
#  68 Iris-versicolor           4.1          1.0           5.8          2.7
#  69 Iris-versicolor           4.5          1.5           6.2          2.2
#  70 Iris-versicolor           3.9          1.1           5.6          2.5
#  71 Iris-versicolor           4.8          1.8           5.9          3.2
#  72 Iris-versicolor           4.0          1.3           6.1          2.8
#  73 Iris-versicolor           4.9          1.5           6.3          2.5
#  74 Iris-versicolor           4.7          1.2           6.1          2.8
#  75 Iris-versicolor           4.3          1.3           6.4          2.9
#  76 Iris-versicolor           4.4          1.4           6.6          3.0
#  77 Iris-versicolor           4.8          1.4           6.8          2.8
#  78 Iris-versicolor           5.0          1.7           6.7          3.0
#  79 Iris-versicolor           4.5          1.5           6.0          2.9
#  80 Iris-versicolor           3.5          1.0           5.7          2.6
#  81 Iris-versicolor           3.8          1.1           5.5          2.4
#  82 Iris-versicolor           3.7          1.0           5.5          2.4
#  83 Iris-versicolor           3.9          1.2           5.8          2.7
#  84 Iris-versicolor           5.1          1.6           6.0          2.7
#  85 Iris-versicolor           4.5          1.5           5.4          3.0
#  86 Iris-versicolor           4.5          1.6           6.0          3.4
#  87 Iris-versicolor           4.7          1.5           6.7          3.1
#  88 Iris-versicolor           4.4          1.3           6.3          2.3
#  89 Iris-versicolor           4.1          1.3           5.6          3.0
#  90 Iris-versicolor           4.0          1.3           5.5          2.5
#  91 Iris-versicolor           4.4          1.2           5.5          2.6
#  92 Iris-versicolor           4.6          1.4           6.1          3.0
#  93 Iris-versicolor           4.0          1.2           5.8          2.6
#  94 Iris-versicolor           3.3          1.0           5.0          2.3
#  95 Iris-versicolor           4.2          1.3           5.6          2.7
#  96 Iris-versicolor           4.2          1.2           5.7          3.0
#  97 Iris-versicolor           4.2          1.3           5.7          2.9
#  98 Iris-versicolor           4.3          1.3           6.2          2.9
#  99 Iris-versicolor           3.0          1.1           5.1          2.5
# 100 Iris-versicolor           4.1          1.3           5.7          2.8
# 101  Iris-virginica          60.0         25.0          20.0         30.0
# 102  Iris-virginica          51.0         19.0          24.0         40.0
# 103  Iris-virginica          59.0         21.0          29.0         35.0
# 104  Iris-virginica          56.0         18.0          28.0         39.0
# 105  Iris-virginica          58.0         22.0          32.0         36.0
# 106  Iris-virginica           6.6          2.1           7.6          3.0
# 107  Iris-virginica           4.5          1.7           4.9          2.5
# 108  Iris-virginica           6.3          1.8           7.3          2.9
# 109  Iris-virginica           5.8          1.8           6.7          2.5
# 110  Iris-virginica           6.1          2.5           7.2          3.6
# 111  Iris-virginica           5.1          2.0           6.5          3.2
# 112  Iris-virginica           5.3          1.9           6.4          2.7
# 113  Iris-virginica           5.5          2.1           6.8          3.0
# 114  Iris-virginica           5.0          2.0           5.7          2.5
# 115  Iris-virginica           5.1          2.4           5.8          2.8
# 116  Iris-virginica           5.3          2.3           6.4          3.2
# 117  Iris-virginica           5.5          1.8           6.5          3.0
# 118  Iris-virginica           6.7          2.2           7.7          3.8
# 119  Iris-virginica           6.9          2.3           7.7          2.6
# 120  Iris-virginica           5.0          1.5           6.0          2.2
# 121  Iris-virginica           5.7          2.3           6.9          3.2
# 122  Iris-virginica           4.9          2.0           5.6          2.8
# 123  Iris-virginica           6.7          2.0           7.7          2.8
# 124  Iris-virginica           4.9          1.8           6.3          2.7
# 125  Iris-virginica           5.7          2.1           6.7          3.3
# 126  Iris-virginica           6.0          1.8           7.2          3.2
# 127  Iris-virginica           4.8          1.8           6.2          2.8
# 128  Iris-virginica           4.9          1.8           6.1          3.0
# 129  Iris-virginica           5.6          2.1           6.4          2.8
# 130  Iris-virginica           5.8          1.6           7.2          3.0
# 131  Iris-virginica           6.1          1.9           7.4          2.8
# 132  Iris-virginica           6.4          2.0           7.9          3.8
# 133  Iris-virginica           5.6          2.2           6.4          2.8
# 134  Iris-virginica           5.1          1.5           6.3          2.8
# 135  Iris-virginica           5.6          1.4           6.1          2.6
# 136  Iris-virginica           6.1          2.3           7.7          3.0
# 137  Iris-virginica           5.6          2.4           6.3          3.4
# 138  Iris-virginica           5.5          1.8           6.4          3.1
# 139  Iris-virginica           4.8          1.8           6.0          3.0
# 140  Iris-virginica           5.4          2.1           6.9          3.1
# 141  Iris-virginica           5.6          2.4           6.7          3.1
# 142  Iris-virginica           5.1          2.3           6.9          3.1
# 143  Iris-virginica           5.1          1.9           5.8          2.7
# 144  Iris-virginica           5.9          2.3           6.8          3.2
# 145  Iris-virginica           5.7          2.5           6.7          3.3
# 146  Iris-virginica           5.2          2.3           6.7          3.0
# 147  Iris-virginica           5.0          1.9           6.3          2.5
# 148  Iris-virginica           5.2          2.0           6.5          3.0
# 149  Iris-virginica           5.4          2.3           6.2          3.4
# 150  Iris-virginica           5.1          1.8           5.9          3.0

# %% [markdown]
# ## **Clustering pada data Iris menggunakan K-Means dengan jumlah cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi clustering
def perform_kmeans(X_scaled, y, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    centroids = kmeans.cluster_centers_
    accuracy = adjusted_rand_score(y, labels)

    print(f"\nHasil K-Means dengan {k} Klaster:")
    print(f"Centroids:\n{centroids}")
    print(f"Akurasi (Adjusted Rand Score): {accuracy:.3f}")

    return labels, centroids, accuracy

# 4. Jalankan clustering
for k in [2, 3, 4]:
    perform_kmeans(X_scaled, y, k)
# Out:
# Hasil K-Means dengan 2 Klaster:
# Centroids:
# [[-0.23249482 -0.24697183 -0.26483417 -0.25756143]
#  [ 2.93788908  3.12082582  3.34654084  3.25463988]]
# Akurasi (Adjusted Rand Score): 0.001
#
# Hasil K-Means dengan 3 Klaster:
# Centroids:
# [[-0.30436152 -0.31706152 -0.2892274  -0.2629765 ]
#  [ 2.63275641  3.10882258  3.62535119  3.58758416]
#  [ 2.95224826  2.34301601  0.55843734 -0.07480289]]
# Akurasi (Adjusted Rand Score): 0.002
#
# Hasil K-Means dengan 4 Klaster:
# Centroids:
# [[-0.30436152 -0.31706152 -0.2892274  -0.2629765 ]
#  [ 3.42251154  4.03307189  4.0965482   4.35738526]
#  [ 2.95224826  2.34301601  0.55843734 -0.07480289]
#  [ 1.84300128  2.18457327  3.15415419  2.81778306]]
# Akurasi (Adjusted Rand Score): 0.005

# %% [markdown]
# ## **Model Plotting dengan Jumlah Cluster 2, 3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi K-Means + plot tanpa cmap
def perform_kmeans_plot(X_scaled, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    centroids = kmeans.cluster_centers_

    plt.figure(figsize=(8, 6))

    # Daftar warna manual (pastikan cukup untuk jumlah klaster)
    colors = ['red', 'gray', 'orange', 'purple']

    for cluster in range(k):
        cluster_points = X_scaled[labels == cluster]
        plt.scatter(
            cluster_points[:, 0], cluster_points[:, 1],
            c=colors[cluster % len(colors)], label=f'Cluster {cluster + 1}',
            s=100, edgecolors='k'
        )

    # Plot centroid
    plt.scatter(
        centroids[:, 0], centroids[:, 1],
        c='black', marker='X', s=200, label='Centroids'
    )

    plt.title(f"K-Means Clustering with {k} Clusters")
    plt.xlabel(feature_names[0])
    plt.ylabel(feature_names[1])
    plt.legend()
    plt.show()

# 4. Jalankan untuk K = 2, 3, dan 4
for k in [2, 3, 4]:
    perform_kmeans_plot(X_scaled, k)

# %% [markdown]
# ## **Menghitung Inertia untuk Jumlah Cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk menghitung inertia secara manual
def calculate_inertia_step_by_step(X_scaled, labels, centroids):
    inertia = 0
    print("Langkah-langkah perhitungan Inertia:")

    for i in range(len(X_scaled)):
        cluster = labels[i]
        distance = np.linalg.norm(X_scaled[i] - centroids[cluster]) ** 2
        inertia += distance
        print(f"Titik data {i+1} (Fitur: {X_scaled[i]}), Klaster: {cluster}, "
              f"Centroid: {centroids[cluster]}, Jarak kuadrat: {distance:.3f}, "
              f"Inertia sementara: {inertia:.3f}")

    return inertia

# 4. Fungsi untuk menjalankan KMeans dan menghitung inertia manual
def perform_kmeans(X_scaled, y, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    centroids = kmeans.cluster_centers_

    print(f"\n=== Hasil K-Means dengan {k} Klaster ===")
    print(f"Centroids (fitur hasil standarisasi):\n{centroids}")

    # Hitung inertia manual
    manual_inertia = calculate_inertia_step_by_step(X_scaled, labels, centroids)
    print(f"\nTotal Inertia Manual: {manual_inertia:.3f}")

    # Bandingkan dengan inertia dari sklearn
    sklearn_inertia = kmeans.inertia_
    print(f"Inertia dari sklearn: {sklearn_inertia:.3f}")
    print("="*50)

    return labels, centroids, manual_inertia

# 5. Jalankan untuk k=2, 3, dan 4
for k in [2, 3, 4]:
    perform_kmeans(X_scaled, y, k)
# Out:
# === Hasil K-Means dengan 2 Klaster ===
# Centroids (fitur hasil standarisasi):
# [[-0.23249482 -0.24697183 -0.26483417 -0.25756143]
#  [ 2.93788908  3.12082582  3.34654084  3.25463988]]
# Langkah-langkah perhitungan Inertia:
# Titik data 1 (Fitur: [ 2.23787885  1.26032396  0.55843734 -0.07480289]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 9.086, Inertia sementara: 9.086
# Titik data 2 (Fitur: [ 5.98921571  3.2408582   0.55843734 -0.07480289]), Klaster: 1, Centroid: [2.93788908 3.12082582 3.34654084 3.25463988], Jarak kuadrat: 28.184, Inertia sementara: 37.270
# Titik data 3 (Fitur: [ 2.05838905  2.18457327  0.4757712  -0.07480289]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 11.742, Inertia sementara: 49.012
# Titik data 4 (Fitur: [ 2.77634825  2.4486445   0.64110348 -0.07480289]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 17.174, Inertia sementara: 66.186
# Titik data 5 (Fitur: [ 1.69940944  2.58068012  0.55843734 -0.07480289]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 12.439, Inertia sementara: 78.625
# Titik data 6 (Fitur: [-0.38267226 -0.20527137 -0.4583562  -0.44803979]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.098, Inertia sementara: 78.723
# Titik data 7 (Fitur: [-0.5262641  -0.27128918 -0.48315604 -0.4713671 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.180, Inertia sementara: 78.903
# Titik data 8 (Fitur: [-0.45446818 -0.27128918 -0.47488943 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.150, Inertia sementara: 79.053
# Titik data 9 (Fitur: [-0.56216206 -0.33730699 -0.48315604 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.221, Inertia sementara: 79.274
# Titik data 10 (Fitur: [-0.47241716 -0.31089986 -0.47488943 -0.51802171]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.174, Inertia sementara: 79.448
# Titik data 11 (Fitur: [-0.38267226 -0.23167849 -0.47488943 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.123, Inertia sementara: 79.571
# Titik data 12 (Fitur: [-0.49036614 -0.27128918 -0.46662281 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.164, Inertia sementara: 79.735
# Titik data 13 (Fitur: [-0.49036614 -0.32410342 -0.48315604 -0.51802171]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.188, Inertia sementara: 79.923
# Titik data 14 (Fitur: [-0.58011104 -0.32410342 -0.50795588 -0.51802171]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.254, Inertia sementara: 80.176
# Titik data 15 (Fitur: [-0.31087634 -0.19206781 -0.49968927 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.121, Inertia sementara: 80.297
# Titik data 16 (Fitur: [-0.32882532 -0.13925356 -0.47488943 -0.44803979]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.101, Inertia sementara: 80.398
# Titik data 17 (Fitur: [-0.38267226 -0.20527137 -0.49142266 -0.44803979]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.112, Inertia sementara: 80.510
# Titik data 18 (Fitur: [-0.4365192  -0.25808562 -0.48315604 -0.4713671 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.135, Inertia sementara: 80.645
# Titik data 19 (Fitur: [-0.32882532 -0.21847493 -0.4583562  -0.4713671 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.093, Inertia sementara: 80.739
# Titik data 20 (Fitur: [-0.4365192  -0.21847493 -0.47488943 -0.4713671 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.132, Inertia sementara: 80.871
# Titik data 21 (Fitur: [-0.38267226 -0.27128918 -0.4583562  -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.117, Inertia sementara: 80.988
# Titik data 22 (Fitur: [-0.4365192  -0.23167849 -0.47488943 -0.44803979]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.122, Inertia sementara: 81.110
# Titik data 23 (Fitur: [-0.5262641  -0.24488206 -0.5162225  -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.206, Inertia sementara: 81.316
# Titik data 24 (Fitur: [-0.4365192  -0.28449274 -0.4583562  -0.42471249]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.108, Inertia sementara: 81.424
# Titik data 25 (Fitur: [-0.49036614 -0.27128918 -0.44182297 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.155, Inertia sementara: 81.579
# Titik data 26 (Fitur: [-0.45446818 -0.32410342 -0.46662281 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.152, Inertia sementara: 81.731
# Titik data 27 (Fitur: [-0.45446818 -0.27128918 -0.46662281 -0.44803979]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.127, Inertia sementara: 81.858
# Titik data 28 (Fitur: [-0.41857022 -0.25808562 -0.47488943 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.135, Inertia sementara: 81.993
# Titik data 29 (Fitur: [-0.41857022 -0.27128918 -0.48315604 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.139, Inertia sementara: 82.132
# Titik data 30 (Fitur: [-0.50831512 -0.2976963  -0.46662281 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.176, Inertia sementara: 82.308
# Titik data 31 (Fitur: [-0.49036614 -0.31089986 -0.46662281 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.168, Inertia sementara: 82.475
# Titik data 32 (Fitur: [-0.38267226 -0.27128918 -0.47488943 -0.44803979]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.104, Inertia sementara: 82.579
# Titik data 33 (Fitur: [-0.41857022 -0.17886425 -0.47488943 -0.51802171]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.151, Inertia sementara: 82.730
# Titik data 34 (Fitur: [-0.36472328 -0.16566069 -0.48315604 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.128, Inertia sementara: 82.858
# Titik data 35 (Fitur: [-0.47241716 -0.31089986 -0.47488943 -0.51802171]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.174, Inertia sementara: 83.031
# Titik data 36 (Fitur: [-0.45446818 -0.2976963  -0.49968927 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.163, Inertia sementara: 83.195
# Titik data 37 (Fitur: [-0.36472328 -0.25808562 -0.49142266 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.125, Inertia sementara: 83.320
# Titik data 38 (Fitur: [-0.47241716 -0.31089986 -0.47488943 -0.51802171]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.174, Inertia sementara: 83.494
# Titik data 39 (Fitur: [-0.56216206 -0.32410342 -0.49142266 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.222, Inertia sementara: 83.716
# Titik data 40 (Fitur: [-0.4365192  -0.27128918 -0.47488943 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.143, Inertia sementara: 83.858
# Titik data 41 (Fitur: [-0.45446818 -0.25808562 -0.49142266 -0.4713671 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.146, Inertia sementara: 84.005
# Titik data 42 (Fitur: [-0.54421308 -0.41652836 -0.49142266 -0.4713671 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.223, Inertia sementara: 84.228
# Titik data 43 (Fitur: [-0.56216206 -0.2976963  -0.49142266 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.219, Inertia sementara: 84.447
# Titik data 44 (Fitur: [-0.45446818 -0.25808562 -0.46662281 -0.40138518]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.111, Inertia sementara: 84.557
# Titik data 45 (Fitur: [-0.4365192  -0.21847493 -0.44182297 -0.44803979]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.110, Inertia sementara: 84.667
# Titik data 46 (Fitur: [-0.49036614 -0.32410342 -0.48315604 -0.4713671 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.166, Inertia sementara: 84.833
# Titik data 47 (Fitur: [-0.4365192  -0.21847493 -0.46662281 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.139, Inertia sementara: 84.973
# Titik data 48 (Fitur: [-0.5262641  -0.2976963  -0.48315604 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.193, Inertia sementara: 85.165
# Titik data 49 (Fitur: [-0.40062124 -0.23167849 -0.47488943 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.129, Inertia sementara: 85.294
# Titik data 50 (Fitur: [-0.45446818 -0.28449274 -0.48315604 -0.4946944 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.155, Inertia sementara: 85.449
# Titik data 51 (Fitur: [1.69940944 1.92050204 3.28642001 2.72447384]), Klaster: 1, Centroid: [2.93788908 3.12082582 3.34654084 3.25463988], Jarak kuadrat: 3.259, Inertia sementara: 88.708
# Titik data 52 (Fitur: [2.05838905 2.05253766 3.12108773 2.9577469 ]), Klaster: 1, Centroid: [2.93788908 3.12082582 3.34654084 3.25463988], Jarak kuadrat: 2.054, Inertia sementara: 90.762
# Titik data 53 (Fitur: [1.87889925 2.18457327 3.4517523  2.9577469 ]), Klaster: 1, Centroid: [2.93788908 3.12082582 3.34654084 3.25463988], Jarak kuadrat: 2.097, Inertia sementara: 92.859
# Titik data 54 (Fitur: [2.23787885 2.31660889 2.70775702 2.49120078]), Klaster: 1, Centroid: [2.93788908 3.12082582 3.34654084 3.25463988], Jarak kuadrat: 2.128, Inertia sementara: 94.987
# Titik data 55 (Fitur: [1.34042984 2.4486445  3.20375387 2.9577469 ]), Klaster: 1, Centroid: [2.93788908 3.12082582 3.34654084 3.25463988], Jarak kuadrat: 3.112, Inertia sementara: 98.099
# Titik data 56 (Fitur: [-0.32882532 -0.35051055 -0.226891   -0.23809404]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.022, Inertia sementara: 98.121
# Titik data 57 (Fitur: [-0.22113144 -0.28449274 -0.21035777 -0.16811212]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.013, Inertia sementara: 98.133
# Titik data 58 (Fitur: [-0.47241716 -0.40332479 -0.32609037 -0.30807596]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.088, Inertia sementara: 98.222
# Titik data 59 (Fitur: [-0.1672845  -0.33730699 -0.21862439 -0.23809404]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.015, Inertia sementara: 98.237
# Titik data 60 (Fitur: [-0.41857022 -0.36371411 -0.27649069 -0.21476673]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.050, Inertia sementara: 98.287
# Titik data 61 (Fitur: [-0.45446818 -0.45613904 -0.30955714 -0.30807596]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.098, Inertia sementara: 98.384
# Titik data 62 (Fitur: [-0.29292736 -0.32410342 -0.25169085 -0.19143943]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.014, Inertia sementara: 98.398
# Titik data 63 (Fitur: [-0.27497838 -0.42973192 -0.26822407 -0.30807596]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.038, Inertia sementara: 98.436
# Titik data 64 (Fitur: [-0.2570294  -0.33730699 -0.21035777 -0.21476673]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.014, Inertia sementara: 98.450
# Titik data 65 (Fitur: [-0.3467743  -0.33730699 -0.30129053 -0.23809404]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.023, Inertia sementara: 98.473
# Titik data 66 (Fitur: [-0.14933552 -0.31089986 -0.23515762 -0.21476673]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.014, Inertia sementara: 98.486
# Titik data 67 (Fitur: [-0.3467743  -0.32410342 -0.226891   -0.19143943]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.025, Inertia sementara: 98.511
# Titik data 68 (Fitur: [-0.31087634 -0.36371411 -0.25995746 -0.30807596]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.022, Inertia sementara: 98.534
# Titik data 69 (Fitur: [-0.23908042 -0.42973192 -0.226891   -0.19143943]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.039, Inertia sementara: 98.573
# Titik data 70 (Fitur: [-0.3467743  -0.39012123 -0.27649069 -0.28474865]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.034, Inertia sementara: 98.607
# Titik data 71 (Fitur: [-0.29292736 -0.2976963  -0.20209116 -0.12145751]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.029, Inertia sementara: 98.636
# Titik data 72 (Fitur: [-0.2570294  -0.35051055 -0.26822407 -0.23809404]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.012, Inertia sementara: 98.648
# Titik data 73 (Fitur: [-0.22113144 -0.39012123 -0.19382455 -0.19143943]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.030, Inertia sementara: 98.678
# Titik data 74 (Fitur: [-0.2570294  -0.35051055 -0.21035777 -0.26142134]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.014, Inertia sementara: 98.692
# Titik data 75 (Fitur: [-0.20318246 -0.33730699 -0.24342423 -0.23809404]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.010, Inertia sementara: 98.702
# Titik data 76 (Fitur: [-0.1672845  -0.32410342 -0.23515762 -0.21476673]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.013, Inertia sementara: 98.715
# Titik data 77 (Fitur: [-0.13138653 -0.35051055 -0.20209116 -0.21476673]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.027, Inertia sementara: 98.742
# Titik data 78 (Fitur: [-0.14933552 -0.32410342 -0.18555793 -0.14478481]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.032, Inertia sementara: 98.773
# Titik data 79 (Fitur: [-0.27497838 -0.33730699 -0.226891   -0.19143943]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.016, Inertia sementara: 98.789
# Titik data 80 (Fitur: [-0.32882532 -0.37691767 -0.30955714 -0.30807596]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.031, Inertia sementara: 98.820
# Titik data 81 (Fitur: [-0.36472328 -0.40332479 -0.2847573  -0.28474865]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.043, Inertia sementara: 98.863
# Titik data 82 (Fitur: [-0.36472328 -0.40332479 -0.29302392 -0.30807596]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.045, Inertia sementara: 98.908
# Titik data 83 (Fitur: [-0.31087634 -0.36371411 -0.27649069 -0.26142134]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.020, Inertia sementara: 98.928
# Titik data 84 (Fitur: [-0.27497838 -0.36371411 -0.17729132 -0.16811212]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.031, Inertia sementara: 98.959
# Titik data 85 (Fitur: [-0.38267226 -0.32410342 -0.226891   -0.19143943]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.034, Inertia sementara: 98.994
# Titik data 86 (Fitur: [-0.27497838 -0.27128918 -0.226891   -0.16811212]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.012, Inertia sementara: 99.005
# Titik data 87 (Fitur: [-0.14933552 -0.31089986 -0.21035777 -0.19143943]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.018, Inertia sementara: 99.024
# Titik data 88 (Fitur: [-0.22113144 -0.41652836 -0.23515762 -0.23809404]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.030, Inertia sementara: 99.054
# Titik data 89 (Fitur: [-0.3467743  -0.32410342 -0.25995746 -0.23809404]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.019, Inertia sementara: 99.073
# Titik data 90 (Fitur: [-0.36472328 -0.39012123 -0.26822407 -0.23809404]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.038, Inertia sementara: 99.112
# Titik data 91 (Fitur: [-0.36472328 -0.37691767 -0.23515762 -0.26142134]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.035, Inertia sementara: 99.147
# Titik data 92 (Fitur: [-0.2570294  -0.32410342 -0.21862439 -0.21476673]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.011, Inertia sementara: 99.157
# Titik data 93 (Fitur: [-0.31087634 -0.37691767 -0.26822407 -0.26142134]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.023, Inertia sementara: 99.181
# Titik data 94 (Fitur: [-0.45446818 -0.41652836 -0.32609037 -0.30807596]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.084, Inertia sementara: 99.265
# Titik data 95 (Fitur: [-0.3467743  -0.36371411 -0.25169085 -0.23809404]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.027, Inertia sementara: 99.292
# Titik data 96 (Fitur: [-0.32882532 -0.32410342 -0.25169085 -0.26142134]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.015, Inertia sementara: 99.307
# Titik data 97 (Fitur: [-0.32882532 -0.33730699 -0.25169085 -0.23809404]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.018, Inertia sementara: 99.325
# Titik data 98 (Fitur: [-0.23908042 -0.33730699 -0.24342423 -0.23809404]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.009, Inertia sementara: 99.335
# Titik data 99 (Fitur: [-0.4365192  -0.39012123 -0.35089022 -0.28474865]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.070, Inertia sementara: 99.405
# Titik data 100 (Fitur: [-0.32882532 -0.35051055 -0.25995746 -0.23809404]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.020, Inertia sementara: 99.425
# Titik data 101 (Fitur: [2.23787885 3.2408582  4.36107985 5.29047751]), Klaster: 1, Centroid: [2.93788908 3.12082582 3.34654084 3.25463988], Jarak kuadrat: 5.678, Inertia sementara: 105.104
# Titik data 102 (Fitur: [2.95583806 4.56121435 3.61708458 3.89083914]), Klaster: 1, Centroid: [2.93788908 3.12082582 3.34654084 3.25463988], Jarak kuadrat: 2.553, Inertia sementara: 107.657
# Titik data 103 (Fitur: [3.85328706 3.90103627 4.27841371 4.35738526]), Klaster: 1, Centroid: [2.93788908 3.12082582 3.34654084 3.25463988], Jarak kuadrat: 3.531, Inertia sementara: 111.188
# Titik data 104 (Fitur: [3.67379726 4.42917874 4.03041529 3.65756608]), Klaster: 1, Centroid: [2.93788908 3.12082582 3.34654084 3.25463988], Jarak kuadrat: 2.883, Inertia sementara: 114.071
# Titik data 105 (Fitur: [4.39175647 4.03307189 4.19574757 4.59065833]), Klaster: 1, Centroid: [2.93788908 3.12082582 3.34654084 3.25463988], Jarak kuadrat: 5.452, Inertia sementara: 119.523
# Titik data 106 (Fitur: [ 0.01220531 -0.32410342 -0.05329211 -0.05147559]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.153, Inertia sementara: 119.676
# Titik data 107 (Fitur: [-0.47241716 -0.39012123 -0.226891   -0.14478481]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.092, Inertia sementara: 119.768
# Titik data 108 (Fitur: [-0.04164163 -0.33730699 -0.07809195 -0.12145751]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.098, Inertia sementara: 119.866
# Titik data 109 (Fitur: [-0.14933552 -0.39012123 -0.11942502 -0.12145751]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.067, Inertia sementara: 119.933
# Titik data 110 (Fitur: [-0.05959061 -0.24488206 -0.09462518  0.04183364]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.149, Inertia sementara: 120.082
# Titik data 111 (Fitur: [-0.18523348 -0.2976963  -0.17729132 -0.07480289]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.046, Inertia sementara: 120.128
# Titik data 112 (Fitur: [-0.20318246 -0.36371411 -0.16075809 -0.0981302 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.051, Inertia sementara: 120.178
# Titik data 113 (Fitur: [-0.13138653 -0.32410342 -0.14422486 -0.05147559]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.073, Inertia sementara: 120.252
# Titik data 114 (Fitur: [-0.32882532 -0.39012123 -0.18555793 -0.07480289]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.069, Inertia sementara: 120.321
# Titik data 115 (Fitur: [-0.31087634 -0.35051055 -0.17729132  0.01850633]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.101, Inertia sementara: 120.422
# Titik data 116 (Fitur: [-0.20318246 -0.2976963  -0.16075809 -0.00482098]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.078, Inertia sementara: 120.500
# Titik data 117 (Fitur: [-0.18523348 -0.32410342 -0.14422486 -0.12145751]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.041, Inertia sementara: 120.541
# Titik data 118 (Fitur: [ 0.03015429 -0.21847493 -0.04502549 -0.02814828]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.171, Inertia sementara: 120.712
# Titik data 119 (Fitur: [ 0.03015429 -0.37691767 -0.02849226 -0.00482098]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.206, Inertia sementara: 120.918
# Titik data 120 (Fitur: [-0.27497838 -0.42973192 -0.18555793 -0.19143943]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.046, Inertia sementara: 120.963
# Titik data 121 (Fitur: [-0.11343755 -0.2976963  -0.12769163 -0.00482098]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.099, Inertia sementara: 121.063
# Titik data 122 (Fitur: [-0.3467743  -0.35051055 -0.19382455 -0.07480289]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.062, Inertia sementara: 121.125
# Titik data 123 (Fitur: [ 0.03015429 -0.35051055 -0.04502549 -0.07480289]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.161, Inertia sementara: 121.287
# Titik data 124 (Fitur: [-0.22113144 -0.36371411 -0.19382455 -0.12145751]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.037, Inertia sementara: 121.324
# Titik data 125 (Fitur: [-0.14933552 -0.28449274 -0.12769163 -0.05147559]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.070, Inertia sementara: 121.393
# Titik data 126 (Fitur: [-0.05959061 -0.2976963  -0.10289179 -0.12145751]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.077, Inertia sementara: 121.471
# Titik data 127 (Fitur: [-0.23908042 -0.35051055 -0.20209116 -0.12145751]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.033, Inertia sementara: 121.504
# Titik data 128 (Fitur: [-0.2570294  -0.32410342 -0.19382455 -0.12145751]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.030, Inertia sementara: 121.534
# Titik data 129 (Fitur: [-0.20318246 -0.35051055 -0.13595825 -0.05147559]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.071, Inertia sementara: 121.605
# Titik data 130 (Fitur: [-0.05959061 -0.32410342 -0.11942502 -0.16811212]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.065, Inertia sementara: 121.670
# Titik data 131 (Fitur: [-0.02369265 -0.35051055 -0.09462518 -0.0981302 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.109, Inertia sementara: 121.778
# Titik data 132 (Fitur: [ 0.06605225 -0.21847493 -0.06982533 -0.07480289]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.161, Inertia sementara: 121.940
# Titik data 133 (Fitur: [-0.20318246 -0.35051055 -0.13595825 -0.02814828]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.081, Inertia sementara: 122.021
# Titik data 134 (Fitur: [-0.22113144 -0.35051055 -0.17729132 -0.19143943]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.023, Inertia sementara: 122.043
# Titik data 135 (Fitur: [-0.2570294  -0.37691767 -0.13595825 -0.21476673]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.036, Inertia sementara: 122.079
# Titik data 136 (Fitur: [ 0.03015429 -0.32410342 -0.09462518 -0.00482098]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.168, Inertia sementara: 122.247
# Titik data 137 (Fitur: [-0.22113144 -0.27128918 -0.13595825  0.01850633]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.094, Inertia sementara: 122.341
# Titik data 138 (Fitur: [-0.20318246 -0.31089986 -0.14422486 -0.12145751]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.038, Inertia sementara: 122.379
# Titik data 139 (Fitur: [-0.27497838 -0.32410342 -0.20209116 -0.12145751]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.030, Inertia sementara: 122.409
# Titik data 140 (Fitur: [-0.11343755 -0.31089986 -0.15249148 -0.05147559]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.073, Inertia sementara: 122.482
# Titik data 141 (Fitur: [-0.14933552 -0.31089986 -0.13595825  0.01850633]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.104, Inertia sementara: 122.586
# Titik data 142 (Fitur: [-0.11343755 -0.31089986 -0.17729132 -0.00482098]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.090, Inertia sementara: 122.676
# Titik data 143 (Fitur: [-0.31087634 -0.36371411 -0.17729132 -0.0981302 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.053, Inertia sementara: 122.729
# Titik data 144 (Fitur: [-0.13138653 -0.2976963  -0.11115841 -0.00482098]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.100, Inertia sementara: 122.829
# Titik data 145 (Fitur: [-0.14933552 -0.28449274 -0.12769163  0.04183364]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.117, Inertia sementara: 122.946
# Titik data 146 (Fitur: [-0.14933552 -0.32410342 -0.1690247  -0.00482098]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.086, Inertia sementara: 123.032
# Titik data 147 (Fitur: [-0.22113144 -0.39012123 -0.18555793 -0.0981302 ]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.052, Inertia sementara: 123.084
# Titik data 148 (Fitur: [-0.18523348 -0.32410342 -0.1690247  -0.07480289]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.051, Inertia sementara: 123.135
# Titik data 149 (Fitur: [-0.23908042 -0.27128918 -0.15249148 -0.00482098]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.077, Inertia sementara: 123.212
# Titik data 150 (Fitur: [-0.29292736 -0.32410342 -0.17729132 -0.12145751]), Klaster: 0, Centroid: [-0.23249482 -0.24697183 -0.26483417 -0.25756143], Jarak kuadrat: 0.036, Inertia sementara: 123.248
#
# Total Inertia Manual: 123.248
# Inertia dari sklearn: 123.248
# ==================================================
#
# === Hasil K-Means dengan 3 Klaster ===
# Centroids (fitur hasil standarisasi):
# [[-0.30436152 -0.31706152 -0.2892274  -0.2629765 ]
#  [ 2.63275641  3.10882258  3.62535119  3.58758416]
#  [ 2.95224826  2.34301601  0.55843734 -0.07480289]]
# Langkah-langkah perhitungan Inertia:
# Titik data 1 (Fitur: [ 2.23787885  1.26032396  0.55843734 -0.07480289]), Klaster: 2, Centroid: [ 2.95224826  2.34301601  0.55843734 -0.07480289], Jarak kuadrat: 1.683, Inertia sementara: 1.683
# Titik data 2 (Fitur: [ 5.98921571  3.2408582   0.55843734 -0.07480289]), Klaster: 2, Centroid: [ 2.95224826  2.34301601  0.55843734 -0.07480289], Jarak kuadrat: 10.029, Inertia sementara: 11.712
# Titik data 3 (Fitur: [ 2.05838905  2.18457327  0.4757712  -0.07480289]), Klaster: 2, Centroid: [ 2.95224826  2.34301601  0.55843734 -0.07480289], Jarak kuadrat: 0.831, Inertia sementara: 12.543
# Titik data 4 (Fitur: [ 2.77634825  2.4486445   0.64110348 -0.07480289]), Klaster: 2, Centroid: [ 2.95224826  2.34301601  0.55843734 -0.07480289], Jarak kuadrat: 0.049, Inertia sementara: 12.592
# Titik data 5 (Fitur: [ 1.69940944  2.58068012  0.55843734 -0.07480289]), Klaster: 2, Centroid: [ 2.95224826  2.34301601  0.55843734 -0.07480289], Jarak kuadrat: 1.626, Inertia sementara: 14.218
# Titik data 6 (Fitur: [-0.38267226 -0.20527137 -0.4583562  -0.44803979]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.081, Inertia sementara: 14.299
# Titik data 7 (Fitur: [-0.5262641  -0.27128918 -0.48315604 -0.4713671 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.132, Inertia sementara: 14.432
# Titik data 8 (Fitur: [-0.45446818 -0.27128918 -0.47488943 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.113, Inertia sementara: 14.544
# Titik data 9 (Fitur: [-0.56216206 -0.33730699 -0.48315604 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.158, Inertia sementara: 14.703
# Titik data 10 (Fitur: [-0.47241716 -0.31089986 -0.47488943 -0.51802171]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.128, Inertia sementara: 14.830
# Titik data 11 (Fitur: [-0.38267226 -0.23167849 -0.47488943 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.102, Inertia sementara: 14.932
# Titik data 12 (Fitur: [-0.49036614 -0.27128918 -0.46662281 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.122, Inertia sementara: 15.054
# Titik data 13 (Fitur: [-0.49036614 -0.32410342 -0.48315604 -0.51802171]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.137, Inertia sementara: 15.191
# Titik data 14 (Fitur: [-0.58011104 -0.32410342 -0.50795588 -0.51802171]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.189, Inertia sementara: 15.380
# Titik data 15 (Fitur: [-0.31087634 -0.19206781 -0.49968927 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.114, Inertia sementara: 15.494
# Titik data 16 (Fitur: [-0.32882532 -0.13925356 -0.47488943 -0.44803979]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.101, Inertia sementara: 15.595
# Titik data 17 (Fitur: [-0.38267226 -0.20527137 -0.49142266 -0.44803979]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.094, Inertia sementara: 15.688
# Titik data 18 (Fitur: [-0.4365192  -0.25808562 -0.48315604 -0.4713671 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.102, Inertia sementara: 15.790
# Titik data 19 (Fitur: [-0.32882532 -0.21847493 -0.4583562  -0.4713671 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.082, Inertia sementara: 15.873
# Titik data 20 (Fitur: [-0.4365192  -0.21847493 -0.47488943 -0.4713671 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.105, Inertia sementara: 15.978
# Titik data 21 (Fitur: [-0.38267226 -0.27128918 -0.4583562  -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.091, Inertia sementara: 16.068
# Titik data 22 (Fitur: [-0.4365192  -0.23167849 -0.47488943 -0.44803979]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.093, Inertia sementara: 16.162
# Titik data 23 (Fitur: [-0.5262641  -0.24488206 -0.5162225  -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.160, Inertia sementara: 16.322
# Titik data 24 (Fitur: [-0.4365192  -0.28449274 -0.4583562  -0.42471249]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.073, Inertia sementara: 16.395
# Titik data 25 (Fitur: [-0.49036614 -0.27128918 -0.44182297 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.114, Inertia sementara: 16.509
# Titik data 26 (Fitur: [-0.45446818 -0.32410342 -0.46662281 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.108, Inertia sementara: 16.616
# Titik data 27 (Fitur: [-0.45446818 -0.27128918 -0.46662281 -0.44803979]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.090, Inertia sementara: 16.707
# Titik data 28 (Fitur: [-0.41857022 -0.25808562 -0.47488943 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.105, Inertia sementara: 16.811
# Titik data 29 (Fitur: [-0.41857022 -0.27128918 -0.48315604 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.106, Inertia sementara: 16.918
# Titik data 30 (Fitur: [-0.50831512 -0.2976963  -0.46662281 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.127, Inertia sementara: 17.045
# Titik data 31 (Fitur: [-0.49036614 -0.31089986 -0.46662281 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.120, Inertia sementara: 17.165
# Titik data 32 (Fitur: [-0.38267226 -0.27128918 -0.47488943 -0.44803979]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.077, Inertia sementara: 17.242
# Titik data 33 (Fitur: [-0.41857022 -0.17886425 -0.47488943 -0.51802171]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.132, Inertia sementara: 17.373
# Titik data 34 (Fitur: [-0.36472328 -0.16566069 -0.48315604 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.118, Inertia sementara: 17.491
# Titik data 35 (Fitur: [-0.47241716 -0.31089986 -0.47488943 -0.51802171]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.128, Inertia sementara: 17.619
# Titik data 36 (Fitur: [-0.45446818 -0.2976963  -0.49968927 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.121, Inertia sementara: 17.740
# Titik data 37 (Fitur: [-0.36472328 -0.25808562 -0.49142266 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.102, Inertia sementara: 17.842
# Titik data 38 (Fitur: [-0.47241716 -0.31089986 -0.47488943 -0.51802171]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.128, Inertia sementara: 17.969
# Titik data 39 (Fitur: [-0.56216206 -0.32410342 -0.49142266 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.161, Inertia sementara: 18.130
# Titik data 40 (Fitur: [-0.4365192  -0.27128918 -0.47488943 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.108, Inertia sementara: 18.238
# Titik data 41 (Fitur: [-0.45446818 -0.25808562 -0.49142266 -0.4713671 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.110, Inertia sementara: 18.348
# Titik data 42 (Fitur: [-0.54421308 -0.41652836 -0.49142266 -0.4713671 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.152, Inertia sementara: 18.500
# Titik data 43 (Fitur: [-0.56216206 -0.2976963  -0.49142266 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.161, Inertia sementara: 18.662
# Titik data 44 (Fitur: [-0.45446818 -0.25808562 -0.46662281 -0.40138518]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.077, Inertia sementara: 18.738
# Titik data 45 (Fitur: [-0.4365192  -0.21847493 -0.44182297 -0.44803979]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.085, Inertia sementara: 18.823
# Titik data 46 (Fitur: [-0.49036614 -0.32410342 -0.48315604 -0.4713671 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.116, Inertia sementara: 18.939
# Titik data 47 (Fitur: [-0.4365192  -0.21847493 -0.46662281 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.112, Inertia sementara: 19.051
# Titik data 48 (Fitur: [-0.5262641  -0.2976963  -0.48315604 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.141, Inertia sementara: 19.192
# Titik data 49 (Fitur: [-0.40062124 -0.23167849 -0.47488943 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.105, Inertia sementara: 19.297
# Titik data 50 (Fitur: [-0.45446818 -0.28449274 -0.48315604 -0.4946944 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.115, Inertia sementara: 19.412
# Titik data 51 (Fitur: [1.69940944 1.92050204 3.28642001 2.72447384]), Klaster: 1, Centroid: [2.63275641 3.10882258 3.62535119 3.58758416], Jarak kuadrat: 3.143, Inertia sementara: 22.555
# Titik data 52 (Fitur: [2.05838905 2.05253766 3.12108773 2.9577469 ]), Klaster: 1, Centroid: [2.63275641 3.10882258 3.62535119 3.58758416], Jarak kuadrat: 2.097, Inertia sementara: 24.651
# Titik data 53 (Fitur: [1.87889925 2.18457327 3.4517523  2.9577469 ]), Klaster: 1, Centroid: [2.63275641 3.10882258 3.62535119 3.58758416], Jarak kuadrat: 1.849, Inertia sementara: 26.501
# Titik data 54 (Fitur: [2.23787885 2.31660889 2.70775702 2.49120078]), Klaster: 1, Centroid: [2.63275641 3.10882258 3.62535119 3.58758416], Jarak kuadrat: 2.828, Inertia sementara: 29.328
# Titik data 55 (Fitur: [1.34042984 2.4486445  3.20375387 2.9577469 ]), Klaster: 1, Centroid: [2.63275641 3.10882258 3.62535119 3.58758416], Jarak kuadrat: 2.680, Inertia sementara: 32.009
# Titik data 56 (Fitur: [-0.32882532 -0.35051055 -0.226891   -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.006, Inertia sementara: 32.015
# Titik data 57 (Fitur: [-0.22113144 -0.28449274 -0.21035777 -0.16811212]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.023, Inertia sementara: 32.038
# Titik data 58 (Fitur: [-0.47241716 -0.40332479 -0.32609037 -0.30807596]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.039, Inertia sementara: 32.077
# Titik data 59 (Fitur: [-0.1672845  -0.33730699 -0.21862439 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.025, Inertia sementara: 32.102
# Titik data 60 (Fitur: [-0.41857022 -0.36371411 -0.27649069 -0.21476673]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.018, Inertia sementara: 32.120
# Titik data 61 (Fitur: [-0.45446818 -0.45613904 -0.30955714 -0.30807596]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.044, Inertia sementara: 32.164
# Titik data 62 (Fitur: [-0.29292736 -0.32410342 -0.25169085 -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.007, Inertia sementara: 32.171
# Titik data 63 (Fitur: [-0.27497838 -0.42973192 -0.26822407 -0.30807596]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.016, Inertia sementara: 32.187
# Titik data 64 (Fitur: [-0.2570294  -0.33730699 -0.21035777 -0.21476673]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.011, Inertia sementara: 32.198
# Titik data 65 (Fitur: [-0.3467743  -0.33730699 -0.30129053 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.003, Inertia sementara: 32.201
# Titik data 66 (Fitur: [-0.14933552 -0.31089986 -0.23515762 -0.21476673]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.029, Inertia sementara: 32.230
# Titik data 67 (Fitur: [-0.3467743  -0.32410342 -0.226891   -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.011, Inertia sementara: 32.241
# Titik data 68 (Fitur: [-0.31087634 -0.36371411 -0.25995746 -0.30807596]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.005, Inertia sementara: 32.246
# Titik data 69 (Fitur: [-0.23908042 -0.42973192 -0.226891   -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.026, Inertia sementara: 32.272
# Titik data 70 (Fitur: [-0.3467743  -0.39012123 -0.27649069 -0.28474865]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.008, Inertia sementara: 32.280
# Titik data 71 (Fitur: [-0.29292736 -0.2976963  -0.20209116 -0.12145751]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.028, Inertia sementara: 32.308
# Titik data 72 (Fitur: [-0.2570294  -0.35051055 -0.26822407 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.004, Inertia sementara: 32.312
# Titik data 73 (Fitur: [-0.22113144 -0.39012123 -0.19382455 -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.026, Inertia sementara: 32.339
# Titik data 74 (Fitur: [-0.2570294  -0.35051055 -0.21035777 -0.26142134]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.010, Inertia sementara: 32.348
# Titik data 75 (Fitur: [-0.20318246 -0.33730699 -0.24342423 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.013, Inertia sementara: 32.362
# Titik data 76 (Fitur: [-0.1672845  -0.32410342 -0.23515762 -0.21476673]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.024, Inertia sementara: 32.386
# Titik data 77 (Fitur: [-0.13138653 -0.35051055 -0.20209116 -0.21476673]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.041, Inertia sementara: 32.427
# Titik data 78 (Fitur: [-0.14933552 -0.32410342 -0.18555793 -0.14478481]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.049, Inertia sementara: 32.476
# Titik data 79 (Fitur: [-0.27497838 -0.33730699 -0.226891   -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.010, Inertia sementara: 32.486
# Titik data 80 (Fitur: [-0.32882532 -0.37691767 -0.30955714 -0.30807596]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.007, Inertia sementara: 32.493
# Titik data 81 (Fitur: [-0.36472328 -0.40332479 -0.2847573  -0.28474865]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.012, Inertia sementara: 32.504
# Titik data 82 (Fitur: [-0.36472328 -0.40332479 -0.29302392 -0.30807596]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.013, Inertia sementara: 32.517
# Titik data 83 (Fitur: [-0.31087634 -0.36371411 -0.27649069 -0.26142134]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.002, Inertia sementara: 32.520
# Titik data 84 (Fitur: [-0.27497838 -0.36371411 -0.17729132 -0.16811212]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.025, Inertia sementara: 32.544
# Titik data 85 (Fitur: [-0.38267226 -0.32410342 -0.226891   -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.015, Inertia sementara: 32.559
# Titik data 86 (Fitur: [-0.27497838 -0.27128918 -0.226891   -0.16811212]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.016, Inertia sementara: 32.575
# Titik data 87 (Fitur: [-0.14933552 -0.31089986 -0.21035777 -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.035, Inertia sementara: 32.611
# Titik data 88 (Fitur: [-0.22113144 -0.41652836 -0.23515762 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.020, Inertia sementara: 32.631
# Titik data 89 (Fitur: [-0.3467743  -0.32410342 -0.25995746 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.003, Inertia sementara: 32.634
# Titik data 90 (Fitur: [-0.36472328 -0.39012123 -0.26822407 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.010, Inertia sementara: 32.644
# Titik data 91 (Fitur: [-0.36472328 -0.37691767 -0.23515762 -0.26142134]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.010, Inertia sementara: 32.654
# Titik data 92 (Fitur: [-0.2570294  -0.32410342 -0.21862439 -0.21476673]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.010, Inertia sementara: 32.664
# Titik data 93 (Fitur: [-0.31087634 -0.37691767 -0.26822407 -0.26142134]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.004, Inertia sementara: 32.668
# ...
# Titik data 70 (Fitur: [-0.3467743  -0.39012123 -0.27649069 -0.28474865]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.008, Inertia sementara: 20.817
# Titik data 71 (Fitur: [-0.29292736 -0.2976963  -0.20209116 -0.12145751]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.028, Inertia sementara: 20.845
# Titik data 72 (Fitur: [-0.2570294  -0.35051055 -0.26822407 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.004, Inertia sementara: 20.849
# Titik data 73 (Fitur: [-0.22113144 -0.39012123 -0.19382455 -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.026, Inertia sementara: 20.876
# Titik data 74 (Fitur: [-0.2570294  -0.35051055 -0.21035777 -0.26142134]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.010, Inertia sementara: 20.886
# Titik data 75 (Fitur: [-0.20318246 -0.33730699 -0.24342423 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.013, Inertia sementara: 20.899
# Titik data 76 (Fitur: [-0.1672845  -0.32410342 -0.23515762 -0.21476673]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.024, Inertia sementara: 20.923
# Titik data 77 (Fitur: [-0.13138653 -0.35051055 -0.20209116 -0.21476673]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.041, Inertia sementara: 20.964
# Titik data 78 (Fitur: [-0.14933552 -0.32410342 -0.18555793 -0.14478481]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.049, Inertia sementara: 21.013
# Titik data 79 (Fitur: [-0.27497838 -0.33730699 -0.226891   -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.010, Inertia sementara: 21.023
# Titik data 80 (Fitur: [-0.32882532 -0.37691767 -0.30955714 -0.30807596]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.007, Inertia sementara: 21.030
# Titik data 81 (Fitur: [-0.36472328 -0.40332479 -0.2847573  -0.28474865]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.012, Inertia sementara: 21.041
# Titik data 82 (Fitur: [-0.36472328 -0.40332479 -0.29302392 -0.30807596]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.013, Inertia sementara: 21.054
# Titik data 83 (Fitur: [-0.31087634 -0.36371411 -0.27649069 -0.26142134]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.002, Inertia sementara: 21.057
# Titik data 84 (Fitur: [-0.27497838 -0.36371411 -0.17729132 -0.16811212]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.025, Inertia sementara: 21.081
# Titik data 85 (Fitur: [-0.38267226 -0.32410342 -0.226891   -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.015, Inertia sementara: 21.096
# Titik data 86 (Fitur: [-0.27497838 -0.27128918 -0.226891   -0.16811212]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.016, Inertia sementara: 21.112
# Titik data 87 (Fitur: [-0.14933552 -0.31089986 -0.21035777 -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.035, Inertia sementara: 21.148
# Titik data 88 (Fitur: [-0.22113144 -0.41652836 -0.23515762 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.020, Inertia sementara: 21.168
# Titik data 89 (Fitur: [-0.3467743  -0.32410342 -0.25995746 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.003, Inertia sementara: 21.171
# Titik data 90 (Fitur: [-0.36472328 -0.39012123 -0.26822407 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.010, Inertia sementara: 21.181
# Titik data 91 (Fitur: [-0.36472328 -0.37691767 -0.23515762 -0.26142134]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.010, Inertia sementara: 21.192
# Titik data 92 (Fitur: [-0.2570294  -0.32410342 -0.21862439 -0.21476673]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.010, Inertia sementara: 21.201
# Titik data 93 (Fitur: [-0.31087634 -0.37691767 -0.26822407 -0.26142134]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.004, Inertia sementara: 21.205
# Titik data 94 (Fitur: [-0.45446818 -0.41652836 -0.32609037 -0.30807596]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.036, Inertia sementara: 21.241
# Titik data 95 (Fitur: [-0.3467743  -0.36371411 -0.25169085 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.006, Inertia sementara: 21.247
# Titik data 96 (Fitur: [-0.32882532 -0.32410342 -0.25169085 -0.26142134]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.002, Inertia sementara: 21.249
# Titik data 97 (Fitur: [-0.32882532 -0.33730699 -0.25169085 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.003, Inertia sementara: 21.252
# Titik data 98 (Fitur: [-0.23908042 -0.33730699 -0.24342423 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.007, Inertia sementara: 21.260
# Titik data 99 (Fitur: [-0.4365192  -0.39012123 -0.35089022 -0.28474865]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.027, Inertia sementara: 21.287
# Titik data 100 (Fitur: [-0.32882532 -0.35051055 -0.25995746 -0.23809404]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.003, Inertia sementara: 21.290
# Titik data 101 (Fitur: [2.23787885 3.2408582  4.36107985 5.29047751]), Klaster: 1, Centroid: [3.42251154 4.03307189 4.0965482  4.35738526], Jarak kuadrat: 2.972, Inertia sementara: 24.261
# Titik data 102 (Fitur: [2.95583806 4.56121435 3.61708458 3.89083914]), Klaster: 1, Centroid: [3.42251154 4.03307189 4.0965482  4.35738526], Jarak kuadrat: 0.944, Inertia sementara: 25.206
# Titik data 103 (Fitur: [3.85328706 3.90103627 4.27841371 4.35738526]), Klaster: 1, Centroid: [3.42251154 4.03307189 4.0965482  4.35738526], Jarak kuadrat: 0.236, Inertia sementara: 25.442
# Titik data 104 (Fitur: [3.67379726 4.42917874 4.03041529 3.65756608]), Klaster: 1, Centroid: [3.42251154 4.03307189 4.0965482  4.35738526], Jarak kuadrat: 0.714, Inertia sementara: 26.156
# Titik data 105 (Fitur: [4.39175647 4.03307189 4.19574757 4.59065833]), Klaster: 1, Centroid: [3.42251154 4.03307189 4.0965482  4.35738526], Jarak kuadrat: 1.004, Inertia sementara: 27.160
# Titik data 106 (Fitur: [ 0.01220531 -0.32410342 -0.05329211 -0.05147559]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.201, Inertia sementara: 27.360
# Titik data 107 (Fitur: [-0.47241716 -0.39012123 -0.226891   -0.14478481]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.051, Inertia sementara: 27.412
# Titik data 108 (Fitur: [-0.04164163 -0.33730699 -0.07809195 -0.12145751]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.134, Inertia sementara: 27.546
# Titik data 109 (Fitur: [-0.14933552 -0.39012123 -0.11942502 -0.12145751]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.078, Inertia sementara: 27.624
# Titik data 110 (Fitur: [-0.05959061 -0.24488206 -0.09462518  0.04183364]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.196, Inertia sementara: 27.820
# Titik data 111 (Fitur: [-0.18523348 -0.2976963  -0.17729132 -0.07480289]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.063, Inertia sementara: 27.882
# Titik data 112 (Fitur: [-0.20318246 -0.36371411 -0.16075809 -0.0981302 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.056, Inertia sementara: 27.939
# Titik data 113 (Fitur: [-0.13138653 -0.32410342 -0.14422486 -0.05147559]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.096, Inertia sementara: 28.034
# Titik data 114 (Fitur: [-0.32882532 -0.39012123 -0.18555793 -0.07480289]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.052, Inertia sementara: 28.086
# Titik data 115 (Fitur: [-0.31087634 -0.35051055 -0.17729132  0.01850633]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.093, Inertia sementara: 28.179
# Titik data 116 (Fitur: [-0.20318246 -0.2976963  -0.16075809 -0.00482098]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.094, Inertia sementara: 28.273
# Titik data 117 (Fitur: [-0.18523348 -0.32410342 -0.14422486 -0.12145751]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.055, Inertia sementara: 28.328
# Titik data 118 (Fitur: [ 0.03015429 -0.21847493 -0.04502549 -0.02814828]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.236, Inertia sementara: 28.565
# Titik data 119 (Fitur: [ 0.03015429 -0.37691767 -0.02849226 -0.00482098]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.250, Inertia sementara: 28.815
# Titik data 120 (Fitur: [-0.27497838 -0.42973192 -0.18555793 -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.029, Inertia sementara: 28.844
# Titik data 121 (Fitur: [-0.11343755 -0.2976963  -0.12769163 -0.00482098]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.130, Inertia sementara: 28.974
# Titik data 122 (Fitur: [-0.3467743  -0.35051055 -0.19382455 -0.07480289]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.047, Inertia sementara: 29.021
# Titik data 123 (Fitur: [ 0.03015429 -0.35051055 -0.04502549 -0.07480289]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.208, Inertia sementara: 29.229
# Titik data 124 (Fitur: [-0.22113144 -0.36371411 -0.19382455 -0.12145751]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.038, Inertia sementara: 29.268
# Titik data 125 (Fitur: [-0.14933552 -0.28449274 -0.12769163 -0.05147559]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.096, Inertia sementara: 29.363
# Titik data 126 (Fitur: [-0.05959061 -0.2976963  -0.10289179 -0.12145751]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.115, Inertia sementara: 29.479
# Titik data 127 (Fitur: [-0.23908042 -0.35051055 -0.20209116 -0.12145751]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.033, Inertia sementara: 29.512
# Titik data 128 (Fitur: [-0.2570294  -0.32410342 -0.19382455 -0.12145751]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.031, Inertia sementara: 29.543
# Titik data 129 (Fitur: [-0.20318246 -0.35051055 -0.13595825 -0.05147559]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.080, Inertia sementara: 29.623
# Titik data 130 (Fitur: [-0.05959061 -0.32410342 -0.11942502 -0.16811212]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.098, Inertia sementara: 29.720
# Titik data 131 (Fitur: [-0.02369265 -0.35051055 -0.09462518 -0.0981302 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.145, Inertia sementara: 29.865
# Titik data 132 (Fitur: [ 0.06605225 -0.21847493 -0.06982533 -0.07480289]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.230, Inertia sementara: 30.096
# Titik data 133 (Fitur: [-0.20318246 -0.35051055 -0.13595825 -0.02814828]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.090, Inertia sementara: 30.186
# Titik data 134 (Fitur: [-0.22113144 -0.35051055 -0.17729132 -0.19143943]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.026, Inertia sementara: 30.211
# Titik data 135 (Fitur: [-0.2570294  -0.37691767 -0.13595825 -0.21476673]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.032, Inertia sementara: 30.243
# Titik data 136 (Fitur: [ 0.03015429 -0.32410342 -0.09462518 -0.00482098]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.216, Inertia sementara: 30.460
# Titik data 137 (Fitur: [-0.22113144 -0.27128918 -0.13595825  0.01850633]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.112, Inertia sementara: 30.571
# Titik data 138 (Fitur: [-0.20318246 -0.31089986 -0.14422486 -0.12145751]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.051, Inertia sementara: 30.623
# Titik data 139 (Fitur: [-0.27497838 -0.32410342 -0.20209116 -0.12145751]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.029, Inertia sementara: 30.651
# Titik data 140 (Fitur: [-0.11343755 -0.31089986 -0.15249148 -0.05147559]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.100, Inertia sementara: 30.751
# Titik data 141 (Fitur: [-0.14933552 -0.31089986 -0.13595825  0.01850633]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.127, Inertia sementara: 30.878
# Titik data 142 (Fitur: [-0.11343755 -0.31089986 -0.17729132 -0.00482098]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.116, Inertia sementara: 30.994
# Titik data 143 (Fitur: [-0.31087634 -0.36371411 -0.17729132 -0.0981302 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.042, Inertia sementara: 31.035
# Titik data 144 (Fitur: [-0.13138653 -0.2976963  -0.11115841 -0.00482098]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.129, Inertia sementara: 31.164
# Titik data 145 (Fitur: [-0.14933552 -0.28449274 -0.12769163  0.04183364]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.144, Inertia sementara: 31.308
# Titik data 146 (Fitur: [-0.14933552 -0.32410342 -0.1690247  -0.00482098]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.105, Inertia sementara: 31.413
# Titik data 147 (Fitur: [-0.22113144 -0.39012123 -0.18555793 -0.0981302 ]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.050, Inertia sementara: 31.464
# Titik data 148 (Fitur: [-0.18523348 -0.32410342 -0.1690247  -0.07480289]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.064, Inertia sementara: 31.528
# Titik data 149 (Fitur: [-0.23908042 -0.27128918 -0.15249148 -0.00482098]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.092, Inertia sementara: 31.619
# Titik data 150 (Fitur: [-0.29292736 -0.32410342 -0.17729132 -0.12145751]), Klaster: 0, Centroid: [-0.30436152 -0.31706152 -0.2892274  -0.2629765 ], Jarak kuadrat: 0.033, Inertia sementara: 31.652
#
# Total Inertia Manual: 31.652
# Inertia dari sklearn: 31.652
# ==================================================

# %% [markdown]
# ## **Model Plotting Diagram Elbow Method**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Hitung inertia untuk berbagai nilai k
inertias = []
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertias.append(kmeans.inertia_)

# 4. Plot Elbow Diagram
plt.figure(figsize=(9, 6))
plt.plot(K_range, inertias, 'bo-', markersize=8, label='Inertia')
plt.title("Metode Elbow - Menentukan Jumlah Klaster Optimal")
plt.xlabel("Jumlah Klaster (k)")
plt.ylabel("Inertia")
plt.xticks(K_range)
plt.grid(True)

# Tambahkan label inertia di tiap titik
for i, inertia in enumerate(inertias):
    plt.text(K_range[i], inertias[i] + 1, f"{inertia:.2f}", ha='center', fontsize=9)

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Menghitung Silhouette Score untuk Jumlah Cluster 2,3 dan 4**

# %%
# 1. Siapkan fitur (X) dan label (y)
feature_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = df_merged[feature_names].values
y = df_merged['class'].astype('category').cat.codes.values  # label dikodekan ke angka

# 2. Standarisasi data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Fungsi untuk melakukan K-Means dan menghitung Silhouette Score
def perform_kmeans_with_silhouette(X_scaled, k):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)

    # Menghitung Silhouette Score
    silhouette_avg = silhouette_score(X_scaled, labels)

    # Centroid dari masing-masing klaster
    centroids = kmeans.cluster_centers_

    # Output hasil untuk klaster k
    print(f"\n=== Hasil K-Means dengan {k} Klaster ===")
    print(f"Centroids:\n{centroids}")
    print(f"Silhouette Score untuk {k} klaster: {silhouette_avg:.3f}")

    return silhouette_avg

# 4. Melakukan clustering dan menghitung Silhouette Score untuk k=2, 3, dan 4
silhouette_scores = []
k_values = [2, 3, 4]

for k in k_values:
    score = perform_kmeans_with_silhouette(X_scaled, k)
    silhouette_scores.append(score)

# 5. Menentukan k dengan Silhouette Score terbaik
best_k = k_values[np.argmax(silhouette_scores)]
best_score = max(silhouette_scores)
print(f"\n>>> Jumlah cluster terbaik dengan dengan Silhouette Score mendekati 1 adalah k = {best_k} (dengan score = {best_score:.3f})")

# 6. Plot Silhouette Scores
plt.figure(figsize=(8, 5))
plt.plot(k_values, silhouette_scores, 'bo-', markersize=8)
plt.title("Silhouette Score untuk Jumlah Klaster yang Berbeda")
plt.xlabel("Jumlah Klaster (k)")
plt.ylabel("Silhouette Score")
plt.xticks(k_values)
plt.grid(True)
plt.show()
# Out:
# === Hasil K-Means dengan 2 Klaster ===
# Centroids:
# [[-0.23249482 -0.24697183 -0.26483417 -0.25756143]
#  [ 2.93788908  3.12082582  3.34654084  3.25463988]]
# Silhouette Score untuk 2 klaster: 0.895
#
# === Hasil K-Means dengan 3 Klaster ===
# Centroids:
# [[-0.30436152 -0.31706152 -0.2892274  -0.2629765 ]
#  [ 2.63275641  3.10882258  3.62535119  3.58758416]
#  [ 2.95224826  2.34301601  0.55843734 -0.07480289]]
# Silhouette Score untuk 3 klaster: 0.883
#
# === Hasil K-Means dengan 4 Klaster ===
# Centroids:
# [[-0.30436152 -0.31706152 -0.2892274  -0.2629765 ]
#  [ 3.42251154  4.03307189  4.0965482   4.35738526]
#  [ 2.95224826  2.34301601  0.55843734 -0.07480289]
#  [ 1.84300128  2.18457327  3.15415419  2.81778306]]
# Silhouette Score untuk 4 klaster: 0.888
#
# >>> Jumlah cluster terbaik dengan dengan Silhouette Score mendekati 1 adalah k = 2 (dengan score = 0.895)
